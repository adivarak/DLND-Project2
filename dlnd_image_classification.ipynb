# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself
#
# "What are all possible labels?" - one of the 10 objects
# "What is the range of values for the image data?" - 0 to 255
# "Are the labels in order or random?" - Random
#
# Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 4
sample_id = 10
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 10:
# Image - Min Value: 44 Max Value: 246
# Image - Shape: (32, 32, 3)
# Label - Label Id: 5 Name: dog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    min_v = np.min(x)
    max_v = np.max(x)

    result =  np.array(x.shape, dtype=np.float32)
    result = (x - min_v)/(max_v - min_v)
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    label_count = 10
    one_hot_labels = np.zeros((len(x), label_count,), dtype=np.uint8)
    for label in range(0, len(x)):
        one_hot_labels[label, x[label]] = 1
    return one_hot_labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf
label_count = 10
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    inputs_placeholder = tf.placeholder(tf.float32, [None, 32, 32, 3], name='x')
    return inputs_placeholder


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    labels_placeholder = tf.placeholder(tf.uint8, [None, label_count,], name='y')
    return labels_placeholder


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    dropout_prob_placeholder = tf.placeholder(tf.float32, name='keep_prob')
    return dropout_prob_placeholder


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    padding = 'VALID'
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0],
                                               conv_ksize[1], 
                                               x_tensor.shape.as_list()[3],
                                               conv_num_outputs], stddev=0.05, dtype=tf.float32))
    bias = tf.Variable(tf.zeros([conv_num_outputs,]), dtype=tf.float32)
    conv2d = tf.nn.conv2d(x_tensor, weights, [1, conv_strides[0], conv_strides[1], 1], padding)
    conv2d = tf.nn.bias_add(conv2d, bias)
    conv2d  = tf.nn.relu(conv2d)
    maxpool = tf.nn.max_pool(conv2d, [1, pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1], padding)
    return maxpool

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    shape = x_tensor.shape.as_list()
    x_tensor = tf.reshape(x_tensor, [-1, shape[1]*shape[2]*shape[3]])
    return x_tensor

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.shape.as_list()
    x = tf.reshape(x_tensor, [-1, 1, shape[1], 1])

    weights = tf.Variable(tf.truncated_normal([1, shape[1], 1, num_outputs], stddev=0.05, dtype=tf.float32), dtype=tf.float32)
    bias    = tf.Variable(tf.zeros([num_outputs,]), dtype=tf.float32)
    fconn   = tf.nn.conv2d(x, weights, [1, 1, 1, 1], 'VALID')
    fconn   = tf.nn.bias_add(fconn, bias)
    fconn   = tf.reshape(fconn, [-1, fconn.shape.as_list()[3]])
    fconn   = tf.nn.relu(fconn)
    return fconn

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    shape = x_tensor.shape.as_list()
    x = tf.reshape(x_tensor, [-1, 1, shape[1], 1])

    weights = tf.Variable(tf.truncated_normal([1, shape[1], 1, num_outputs], stddev=0.05, dtype=tf.float32), dtype=tf.float32)
    bias    = tf.Variable(tf.zeros([num_outputs,]), dtype=tf.float32)
    fconn   = tf.nn.conv2d(x, weights, [1, 1, 1, 1], 'VALID')
    fconn   = tf.nn.bias_add(fconn, bias)
    fconn   = tf.reshape(fconn, [-1, fconn.shape.as_list()[3]])
    
    return fconn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    l12 = conv2d_maxpool(x, 48, [5, 5], [1, 1], [3, 3], [1, 1])      #N x 32 x 32 x 96
    l34 = conv2d_maxpool(l12, 96, [3, 3], [1, 1], [2, 2], [2, 2])   #N x 16 x 16 x 192
    l56 = conv2d_maxpool(l34, 192, [3, 3], [1, 1], [2, 2], [2, 2])   #N x 8 x 8 x 192
    l56 = tf.nn.dropout(l56, keep_prob)
    l78 = conv2d_maxpool(l56, 384, [3, 3], [1, 1], [2, 2], [2, 2])   #N x 4 x 4 x 192

    l78 = flatten(l78)

    l11 = fully_conn(l78, 2048)
    l11 = tf.nn.dropout(l11, keep_prob)
    l12 = fully_conn(l11, 1024)
    l12 = tf.nn.dropout(l12, keep_prob)
    
    logits = output(l12, 10)
    
    return logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict = {keep_prob: keep_probability,
                                        x: feature_batch,
                                        y: label_batch})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    print(len(valid_labels))
    training_loss = session.run(cost, feed_dict={keep_prob: 1.0, x: feature_batch, y:label_batch})
    training_acc = session.run(accuracy, feed_dict={keep_prob: 1.0, x: feature_batch, y:label_batch})
    valid_acc = session.run(accuracy, feed_dict={keep_prob:1.0, x: valid_features, y: valid_labels})
    print('training loss       : {}\n\
training accuracy : {}\n\
valid    accuracy : {}\n'.format(training_loss, training_acc, valid_acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 10
batch_size = 128
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  \n'.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# 5000
# training loss       : 2.102475643157959
# training accuracy : 0.2750000059604645
# valid    accuracy : 0.23479998111724854
#
# Epoch  2, CIFAR-10 Batch 1:
# 5000
# training loss       : 2.0252792835235596
# training accuracy : 0.22499999403953552
# valid    accuracy : 0.25039994716644287
#
# Epoch  3, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.789698839187622
# training accuracy : 0.4750000238418579
# valid    accuracy : 0.36799997091293335
#
# Epoch  4, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.6628847122192383
# training accuracy : 0.4000000059604645
# valid    accuracy : 0.4299999475479126
#
# Epoch  5, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.484521746635437
# training accuracy : 0.5249999761581421
# valid    accuracy : 0.4451999366283417
#
# Epoch  6, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.4032158851623535
# training accuracy : 0.5250000357627869
# valid    accuracy : 0.4745999872684479
#
# Epoch  7, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.2684853076934814
# training accuracy : 0.6000000238418579
# valid    accuracy : 0.4699999690055847
#
# Epoch  8, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.164232850074768
# training accuracy : 0.574999988079071
# valid    accuracy : 0.4723999798297882
#
# Epoch  9, CIFAR-10 Batch 1:
# 5000
# training loss       : 1.1603186130523682
# training accuracy : 0.625
# valid    accuracy : 0.5025999546051025
#
# Epoch 10, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.9724259376525879
# training accuracy : 0.6499999761581421
# valid    accuracy : 0.5041999816894531
#
# Epoch 11, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.9684582948684692
# training accuracy : 0.7000000476837158
# valid    accuracy : 0.5123999714851379
#
# Epoch 12, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.815769612789154
# training accuracy : 0.75
# valid    accuracy : 0.5455999374389648
#
# Epoch 13, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.8593116402626038
# training accuracy : 0.7250000238418579
# valid    accuracy : 0.5363999605178833
#
# Epoch 14, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.692257285118103
# training accuracy : 0.75
# valid    accuracy : 0.5623999238014221
#
# Epoch 15, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.639091968536377
# training accuracy : 0.8250000476837158
# valid    accuracy : 0.5401999354362488
#
# Epoch 16, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.5321254134178162
# training accuracy : 0.875
# valid    accuracy : 0.5697999596595764
#
# Epoch 17, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.5118076205253601
# training accuracy : 0.8500000834465027
# valid    accuracy : 0.5571999549865723
#
# Epoch 18, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.42899638414382935
# training accuracy : 0.875
# valid    accuracy : 0.5679999589920044
#
# Epoch 19, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.45899033546447754
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.5687999725341797
#
# Epoch 20, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.36503908038139343
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.5493999123573303
#
# Epoch 21, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.27982425689697266
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.5637999176979065
#
# Epoch 22, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.26801156997680664
# training accuracy : 0.925000011920929
# valid    accuracy : 0.5473999381065369
#
# Epoch 23, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.15208536386489868
# training accuracy : 1.0
# valid    accuracy : 0.5763999223709106
#
# Epoch 24, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.17216061055660248
# training accuracy : 1.0
# valid    accuracy : 0.5727999210357666
#
# Epoch 25, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.247263103723526
# training accuracy : 0.949999988079071
# valid    accuracy : 0.5427999496459961
#
# Epoch 26, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.12753534317016602
# training accuracy : 1.0
# valid    accuracy : 0.5615999698638916
#
# Epoch 27, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.17164376378059387
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.538599967956543
#
# Epoch 28, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.09432143718004227
# training accuracy : 1.0
# valid    accuracy : 0.5521999597549438
#
# Epoch 29, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.07334575802087784
# training accuracy : 1.0
# valid    accuracy : 0.555199921131134
#
# Epoch 30, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.05848178267478943
# training accuracy : 1.0
# valid    accuracy : 0.58079993724823
#
# Epoch 31, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.06628082692623138
# training accuracy : 1.0
# valid    accuracy : 0.5801998972892761
#
# Epoch 32, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.07405631989240646
# training accuracy : 1.0
# valid    accuracy : 0.5655999779701233
#
# Epoch 33, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.05058697983622551
# training accuracy : 1.0
# valid    accuracy : 0.5651999711990356
#
# Epoch 34, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.03490270674228668
# training accuracy : 1.0
# valid    accuracy : 0.5627999305725098
#
# Epoch 35, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.03455164656043053
# training accuracy : 1.0
# valid    accuracy : 0.5657999515533447
#
# Epoch 36, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.03922544792294502
# training accuracy : 1.0
# valid    accuracy : 0.5747998952865601
#
# Epoch 37, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.014998394064605236
# training accuracy : 1.0
# valid    accuracy : 0.5657999515533447
#
# Epoch 38, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.04117794707417488
# training accuracy : 1.0
# valid    accuracy : 0.5525999665260315
#
# Epoch 39, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.023985382169485092
# training accuracy : 1.0
# valid    accuracy : 0.5647999048233032
#
# Epoch 40, CIFAR-10 Batch 1:
# 5000
# training loss       : 0.01546038594096899
# training accuracy : 1.0
# valid    accuracy : 0.5451999306678772

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
epochs = 40
keep_probability = 0.5

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  5000
# training loss       : 2.1149826049804688
# training accuracy : 0.25
# valid    accuracy : 0.26739999651908875
#
# Epoch  1, CIFAR-10 Batch 2:  5000
# training loss       : 1.8053086996078491
# training accuracy : 0.42500001192092896
# valid    accuracy : 0.3367999792098999
#
# Epoch  1, CIFAR-10 Batch 3:  5000
# training loss       : 1.3657503128051758
# training accuracy : 0.4750000238418579
# valid    accuracy : 0.38659998774528503
#
# Epoch  1, CIFAR-10 Batch 4:  5000
# training loss       : 1.5832595825195312
# training accuracy : 0.32500001788139343
# valid    accuracy : 0.4373999834060669
#
# Epoch  1, CIFAR-10 Batch 5:  5000
# training loss       : 1.5548826456069946
# training accuracy : 0.42500001192092896
# valid    accuracy : 0.4907999336719513
#
# Epoch  2, CIFAR-10 Batch 1:  5000
# training loss       : 1.5837005376815796
# training accuracy : 0.5
# valid    accuracy : 0.47359994053840637
#
# Epoch  2, CIFAR-10 Batch 2:  5000
# training loss       : 1.415999412536621
# training accuracy : 0.4750000238418579
# valid    accuracy : 0.48899996280670166
#
# Epoch  2, CIFAR-10 Batch 3:  5000
# training loss       : 1.0499063730239868
# training accuracy : 0.7000000476837158
# valid    accuracy : 0.5161999464035034
#
# Epoch  2, CIFAR-10 Batch 4:  5000
# training loss       : 1.2039588689804077
# training accuracy : 0.5
# valid    accuracy : 0.52239990234375
#
# Epoch  2, CIFAR-10 Batch 5:  5000
# training loss       : 1.366171956062317
# training accuracy : 0.5250000357627869
# valid    accuracy : 0.5361999273300171
#
# Epoch  3, CIFAR-10 Batch 1:  5000
# training loss       : 1.2496426105499268
# training accuracy : 0.550000011920929
# valid    accuracy : 0.5689999461174011
#
# Epoch  3, CIFAR-10 Batch 2:  5000
# training loss       : 1.181546926498413
# training accuracy : 0.6000000238418579
# valid    accuracy : 0.5375999808311462
#
# Epoch  3, CIFAR-10 Batch 3:  5000
# training loss       : 1.0127620697021484
# training accuracy : 0.625
# valid    accuracy : 0.5703999400138855
#
# Epoch  3, CIFAR-10 Batch 4:  5000
# training loss       : 0.9758708477020264
# training accuracy : 0.6000000238418579
# valid    accuracy : 0.5669999122619629
#
# Epoch  3, CIFAR-10 Batch 5:  5000
# training loss       : 1.1143395900726318
# training accuracy : 0.6000000238418579
# valid    accuracy : 0.5879999399185181
#
# Epoch  4, CIFAR-10 Batch 1:  5000
# training loss       : 1.182278037071228
# training accuracy : 0.574999988079071
# valid    accuracy : 0.5805999040603638
#
# Epoch  4, CIFAR-10 Batch 2:  5000
# training loss       : 1.0989141464233398
# training accuracy : 0.5750000476837158
# valid    accuracy : 0.5737999081611633
#
# Epoch  4, CIFAR-10 Batch 3:  5000
# training loss       : 0.7811176776885986
# training accuracy : 0.8000000715255737
# valid    accuracy : 0.6233999133110046
#
# Epoch  4, CIFAR-10 Batch 4:  5000
# training loss       : 0.8290809392929077
# training accuracy : 0.7500000596046448
# valid    accuracy : 0.5969998836517334
#
# Epoch  4, CIFAR-10 Batch 5:  5000
# training loss       : 0.8859829306602478
# training accuracy : 0.75
# valid    accuracy : 0.6303998827934265
#
# Epoch  5, CIFAR-10 Batch 1:  5000
# training loss       : 1.0536572933197021
# training accuracy : 0.6749999523162842
# valid    accuracy : 0.6315999031066895
#
# Epoch  5, CIFAR-10 Batch 2:  5000
# training loss       : 1.001413106918335
# training accuracy : 0.6749999523162842
# valid    accuracy : 0.6119999289512634
#
# Epoch  5, CIFAR-10 Batch 3:  5000
# training loss       : 0.6968809366226196
# training accuracy : 0.8000000715255737
# valid    accuracy : 0.6291999220848083
#
# Epoch  5, CIFAR-10 Batch 4:  5000
# training loss       : 0.8297365307807922
# training accuracy : 0.699999988079071
# valid    accuracy : 0.6307998895645142
#
# Epoch  5, CIFAR-10 Batch 5:  5000
# training loss       : 0.7541154623031616
# training accuracy : 0.7250000238418579
# valid    accuracy : 0.6355999112129211
#
# Epoch  6, CIFAR-10 Batch 1:  5000
# training loss       : 0.9879124164581299
# training accuracy : 0.6499999761581421
# valid    accuracy : 0.6363998651504517
#
# Epoch  6, CIFAR-10 Batch 2:  5000
# training loss       : 0.8511185050010681
# training accuracy : 0.675000011920929
# valid    accuracy : 0.6431999206542969
#
# Epoch  6, CIFAR-10 Batch 3:  5000
# training loss       : 0.566339373588562
# training accuracy : 0.824999988079071
# valid    accuracy : 0.6573998928070068
#
# Epoch  6, CIFAR-10 Batch 4:  5000
# training loss       : 0.7385563254356384
# training accuracy : 0.7750000357627869
# valid    accuracy : 0.6467999219894409
#
# Epoch  6, CIFAR-10 Batch 5:  5000
# training loss       : 0.6485482454299927
# training accuracy : 0.8250000476837158
# valid    accuracy : 0.6607998609542847
#
# Epoch  7, CIFAR-10 Batch 1:  5000
# training loss       : 0.9093136787414551
# training accuracy : 0.625
# valid    accuracy : 0.66159987449646
#
# Epoch  7, CIFAR-10 Batch 2:  5000
# training loss       : 0.7105094194412231
# training accuracy : 0.75
# valid    accuracy : 0.6653999090194702
#
# Epoch  7, CIFAR-10 Batch 3:  5000
# training loss       : 0.6027978658676147
# training accuracy : 0.8500000834465027
# valid    accuracy : 0.6481999158859253
#
# Epoch  7, CIFAR-10 Batch 4:  5000
# training loss       : 0.502964973449707
# training accuracy : 0.875
# valid    accuracy : 0.6655999422073364
#
# Epoch  7, CIFAR-10 Batch 5:  5000
# training loss       : 0.6251323223114014
# training accuracy : 0.8000000715255737
# valid    accuracy : 0.673599898815155
#
# Epoch  8, CIFAR-10 Batch 1:  5000
# training loss       : 0.779638409614563
# training accuracy : 0.7250000238418579
# valid    accuracy : 0.6595999002456665
#
# Epoch  8, CIFAR-10 Batch 2:  5000
# training loss       : 0.7598518133163452
# training accuracy : 0.75
# valid    accuracy : 0.6639999151229858
#
# Epoch  8, CIFAR-10 Batch 3:  5000
# training loss       : 0.5046761631965637
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6761999130249023
#
# Epoch  8, CIFAR-10 Batch 4:  5000
# training loss       : 0.4838292598724365
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6715998649597168
#
# Epoch  8, CIFAR-10 Batch 5:  5000
# training loss       : 0.5511308312416077
# training accuracy : 0.8500000238418579
# valid    accuracy : 0.6899998784065247
#
# Epoch  9, CIFAR-10 Batch 1:  5000
# training loss       : 0.7420738935470581
# training accuracy : 0.7000000476837158
# valid    accuracy : 0.6693999171257019
#
# Epoch  9, CIFAR-10 Batch 2:  5000
# training loss       : 0.6236059665679932
# training accuracy : 0.8000000715255737
# valid    accuracy : 0.6691998243331909
#
# Epoch  9, CIFAR-10 Batch 3:  5000
# training loss       : 0.45278865098953247
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6833999156951904
#
# Epoch  9, CIFAR-10 Batch 4:  5000
# training loss       : 0.41771936416625977
# training accuracy : 0.8500000238418579
# valid    accuracy : 0.6905998587608337
#
# Epoch  9, CIFAR-10 Batch 5:  5000
# training loss       : 0.5034855008125305
# training accuracy : 0.8250000476837158
# valid    accuracy : 0.7017998695373535
#
# Epoch 10, CIFAR-10 Batch 1:  5000
# training loss       : 0.6059037446975708
# training accuracy : 0.7250000238418579
# valid    accuracy : 0.6867998838424683
#
# Epoch 10, CIFAR-10 Batch 2:  5000
# training loss       : 0.5871719717979431
# training accuracy : 0.8250000476837158
# valid    accuracy : 0.6973998546600342
#
# Epoch 10, CIFAR-10 Batch 3:  5000
# training loss       : 0.39706951379776
# training accuracy : 0.875
# valid    accuracy : 0.6789999008178711
#
# Epoch 10, CIFAR-10 Batch 4:  5000
# training loss       : 0.3257862627506256
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6775999069213867
#
# Epoch 10, CIFAR-10 Batch 5:  5000
# training loss       : 0.4649971127510071
# training accuracy : 0.8500000238418579
# valid    accuracy : 0.6793999075889587
#
# Epoch 11, CIFAR-10 Batch 1:  5000
# training loss       : 0.5670626163482666
# training accuracy : 0.824999988079071
# valid    accuracy : 0.6827999353408813
#
# Epoch 11, CIFAR-10 Batch 2:  5000
# training loss       : 0.511971116065979
# training accuracy : 0.875
# valid    accuracy : 0.6789998412132263
#
# Epoch 11, CIFAR-10 Batch 3:  5000
# training loss       : 0.4613489806652069
# training accuracy : 0.8250000476837158
# valid    accuracy : 0.6579998731613159
#
# Epoch 11, CIFAR-10 Batch 4:  5000
# training loss       : 0.3359534740447998
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6835998296737671
#
# Epoch 11, CIFAR-10 Batch 5:  5000
# training loss       : 0.3741670846939087
# training accuracy : 0.8999999761581421
# valid    accuracy : 0.6933998465538025
#
# Epoch 12, CIFAR-10 Batch 1:  5000
# training loss       : 0.5325527191162109
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6791999340057373
#
# Epoch 12, CIFAR-10 Batch 2:  5000
# training loss       : 0.45987728238105774
# training accuracy : 0.8500000238418579
# valid    accuracy : 0.6935998797416687
#
# Epoch 12, CIFAR-10 Batch 3:  5000
# training loss       : 0.34697192907333374
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6645998954772949
#
# Epoch 12, CIFAR-10 Batch 4:  5000
# training loss       : 0.33144959807395935
# training accuracy : 0.925000011920929
# valid    accuracy : 0.68479984998703
#
# Epoch 12, CIFAR-10 Batch 5:  5000
# training loss       : 0.37862128019332886
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6993998885154724
#
# Epoch 13, CIFAR-10 Batch 1:  5000
# training loss       : 0.4246436357498169
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.6963998079299927
#
# Epoch 13, CIFAR-10 Batch 2:  5000
# training loss       : 0.42160797119140625
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6951999068260193
#
# Epoch 13, CIFAR-10 Batch 3:  5000
# training loss       : 0.30898231267929077
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6919999122619629
#
# Epoch 13, CIFAR-10 Batch 4:  5000
# training loss       : 0.2938944101333618
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.6963998079299927
#
# Epoch 13, CIFAR-10 Batch 5:  5000
# training loss       : 0.3224656879901886
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7063999176025391
#
# Epoch 14, CIFAR-10 Batch 1:  5000
# training loss       : 0.4576752483844757
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6851999163627625
#
# Epoch 14, CIFAR-10 Batch 2:  5000
# training loss       : 0.3463483452796936
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6903998255729675
#
# Epoch 14, CIFAR-10 Batch 3:  5000
# training loss       : 0.34923940896987915
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.6759998798370361
#
# Epoch 14, CIFAR-10 Batch 4:  5000
# training loss       : 0.24821294844150543
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7077998518943787
#
# Epoch 14, CIFAR-10 Batch 5:  5000
# training loss       : 0.2750028073787689
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7123998403549194
#
# Epoch 15, CIFAR-10 Batch 1:  5000
# training loss       : 0.40458887815475464
# training accuracy : 0.875
# valid    accuracy : 0.6945998668670654
#
# Epoch 15, CIFAR-10 Batch 2:  5000
# training loss       : 0.2799597382545471
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7053998708724976
#
# Epoch 15, CIFAR-10 Batch 3:  5000
# training loss       : 0.2399294376373291
# training accuracy : 0.8750000596046448
# valid    accuracy : 0.6953998804092407
#
# Epoch 15, CIFAR-10 Batch 4:  5000
# training loss       : 0.2745860815048218
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7019999027252197
#
# Epoch 15, CIFAR-10 Batch 5:  5000
# training loss       : 0.3267982304096222
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.7045997977256775
#
# Epoch 16, CIFAR-10 Batch 1:  5000
# training loss       : 0.3608616292476654
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6911998987197876
#
# Epoch 16, CIFAR-10 Batch 2:  5000
# training loss       : 0.22471176087856293
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7133998274803162
#
# Epoch 16, CIFAR-10 Batch 3:  5000
# training loss       : 0.26348018646240234
# training accuracy : 0.925000011920929
# valid    accuracy : 0.6819998621940613
#
# Epoch 16, CIFAR-10 Batch 4:  5000
# training loss       : 0.16721084713935852
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7119998335838318
#
# Epoch 16, CIFAR-10 Batch 5:  5000
# training loss       : 0.2520790696144104
# training accuracy : 0.9750000238418579
# valid    accuracy : 0.6997998952865601
#
# Epoch 17, CIFAR-10 Batch 1:  5000
# training loss       : 0.38977155089378357
# training accuracy : 0.8500000238418579
# valid    accuracy : 0.6997997760772705
#
# Epoch 17, CIFAR-10 Batch 2:  5000
# training loss       : 0.27637583017349243
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7109999060630798
#
# Epoch 17, CIFAR-10 Batch 3:  5000
# training loss       : 0.15549789369106293
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7041998505592346
#
# Epoch 17, CIFAR-10 Batch 4:  5000
# training loss       : 0.1913682073354721
# training accuracy : 1.0
# valid    accuracy : 0.715799868106842
#
# Epoch 17, CIFAR-10 Batch 5:  5000
# training loss       : 0.16281121969223022
# training accuracy : 1.0
# valid    accuracy : 0.715799868106842
#
# Epoch 18, CIFAR-10 Batch 1:  5000
# training loss       : 0.32860174775123596
# training accuracy : 0.949999988079071
# valid    accuracy : 0.6937998533248901
#
# Epoch 18, CIFAR-10 Batch 2:  5000
# training loss       : 0.21009275317192078
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.691399872303009
#
# Epoch 18, CIFAR-10 Batch 3:  5000
# training loss       : 0.2812463343143463
# training accuracy : 0.925000011920929
# valid    accuracy : 0.6923998594284058
#
# Epoch 18, CIFAR-10 Batch 4:  5000
# training loss       : 0.15492118895053864
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7059998512268066
#
# Epoch 18, CIFAR-10 Batch 5:  5000
# training loss       : 0.21244825422763824
# training accuracy : 1.0
# valid    accuracy : 0.7163998484611511
#
# Epoch 19, CIFAR-10 Batch 1:  5000
# training loss       : 0.2650851607322693
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.708599865436554
#
# Epoch 19, CIFAR-10 Batch 2:  5000
# training loss       : 0.15214282274246216
# training accuracy : 1.0
# valid    accuracy : 0.7217998504638672
#
# Epoch 19, CIFAR-10 Batch 3:  5000
# training loss       : 0.2080371379852295
# training accuracy : 0.925000011920929
# valid    accuracy : 0.719799816608429
#
# Epoch 19, CIFAR-10 Batch 4:  5000
# training loss       : 0.13091763854026794
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7123998403549194
#
# Epoch 19, CIFAR-10 Batch 5:  5000
# training loss       : 0.17043955624103546
# training accuracy : 1.0
# valid    accuracy : 0.7217997908592224
#
# Epoch 20, CIFAR-10 Batch 1:  5000
# training loss       : 0.3037607669830322
# training accuracy : 0.9000000357627869
# valid    accuracy : 0.6907998323440552
#
# Epoch 20, CIFAR-10 Batch 2:  5000
# training loss       : 0.18233242630958557
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7221997976303101
#
# Epoch 20, CIFAR-10 Batch 3:  5000
# training loss       : 0.17167825996875763
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7109998464584351
#
# Epoch 20, CIFAR-10 Batch 4:  5000
# training loss       : 0.16145196557044983
# training accuracy : 1.0
# valid    accuracy : 0.6991998553276062
#
# Epoch 20, CIFAR-10 Batch 5:  5000
# training loss       : 0.18641912937164307
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7193998098373413
#
# Epoch 21, CIFAR-10 Batch 1:  5000
# training loss       : 0.23153415322303772
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7121999263763428
#
# Epoch 21, CIFAR-10 Batch 2:  5000
# training loss       : 0.16519522666931152
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7041997909545898
#
# Epoch 21, CIFAR-10 Batch 3:  5000
# training loss       : 0.18781961500644684
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7023999094963074
#
# Epoch 21, CIFAR-10 Batch 4:  5000
# training loss       : 0.13654401898384094
# training accuracy : 1.0
# valid    accuracy : 0.7197998762130737
#
# Epoch 21, CIFAR-10 Batch 5:  5000
# training loss       : 0.16804659366607666
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7131998538970947
#
# Epoch 22, CIFAR-10 Batch 1:  5000
# training loss       : 0.20385535061359406
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7095999121665955
#
# Epoch 22, CIFAR-10 Batch 2:  5000
# training loss       : 0.16847483813762665
# training accuracy : 1.0
# valid    accuracy : 0.7175998687744141
#
# Epoch 22, CIFAR-10 Batch 3:  5000
# training loss       : 0.15760251879692078
# training accuracy : 0.949999988079071
# valid    accuracy : 0.71319979429245
#
# Epoch 22, CIFAR-10 Batch 4:  5000
# training loss       : 0.1769811362028122
# training accuracy : 1.0
# valid    accuracy : 0.7087998986244202
#
# Epoch 22, CIFAR-10 Batch 5:  5000
# training loss       : 0.14570529758930206
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7325998544692993
#
# Epoch 23, CIFAR-10 Batch 1:  5000
# training loss       : 0.24627888202667236
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7017998695373535
#
# Epoch 23, CIFAR-10 Batch 2:  5000
# training loss       : 0.16717956960201263
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7071998119354248
#
# Epoch 23, CIFAR-10 Batch 3:  5000
# training loss       : 0.16779181361198425
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7221998572349548
#
# Epoch 23, CIFAR-10 Batch 4:  5000
# training loss       : 0.12413361668586731
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7195999026298523
#
# Epoch 23, CIFAR-10 Batch 5:  5000
# training loss       : 0.2105862945318222
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7181998491287231
#
# Epoch 24, CIFAR-10 Batch 1:  5000
# training loss       : 0.2068621814250946
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7113999128341675
#
# Epoch 24, CIFAR-10 Batch 2:  5000
# training loss       : 0.11836883425712585
# training accuracy : 1.0
# valid    accuracy : 0.7155998349189758
#
# Epoch 24, CIFAR-10 Batch 3:  5000
# training loss       : 0.15982288122177124
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7245998382568359
#
# Epoch 24, CIFAR-10 Batch 4:  5000
# training loss       : 0.1201724112033844
# training accuracy : 0.9750000238418579
# valid    accuracy : 0.7061998844146729
#
# Epoch 24, CIFAR-10 Batch 5:  5000
# training loss       : 0.15737880766391754
# training accuracy : 0.9750000238418579
# valid    accuracy : 0.7161998748779297
#
# Epoch 25, CIFAR-10 Batch 1:  5000
# training loss       : 0.15737640857696533
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7143998742103577
#
# Epoch 25, CIFAR-10 Batch 2:  5000
# training loss       : 0.14272171258926392
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7141998410224915
#
# Epoch 25, CIFAR-10 Batch 3:  5000
# training loss       : 0.14215272665023804
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7179998159408569
#
# Epoch 25, CIFAR-10 Batch 4:  5000
# training loss       : 0.09578214585781097
# training accuracy : 1.0
# valid    accuracy : 0.7263998985290527
#
# Epoch 25, CIFAR-10 Batch 5:  5000
# training loss       : 0.1368614137172699
# training accuracy : 0.949999988079071
# valid    accuracy : 0.7249997854232788
#
# Epoch 26, CIFAR-10 Batch 1:  5000
# training loss       : 0.13694816827774048
# training accuracy : 0.949999988079071
# valid    accuracy : 0.718799889087677
#
# Epoch 26, CIFAR-10 Batch 2:  5000
# training loss       : 0.1273636519908905
# training accuracy : 1.0
# valid    accuracy : 0.7237998247146606
#
# Epoch 26, CIFAR-10 Batch 3:  5000
# training loss       : 0.09286448359489441
# training accuracy : 1.0
# valid    accuracy : 0.7293998599052429
#
# Epoch 26, CIFAR-10 Batch 4:  5000
# training loss       : 0.1509290486574173
# training accuracy : 1.0
# valid    accuracy : 0.708599865436554
#
# Epoch 26, CIFAR-10 Batch 5:  5000
# training loss       : 0.16736818850040436
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7177998423576355
#
# Epoch 27, CIFAR-10 Batch 1:  5000
# training loss       : 0.22418221831321716
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7071998715400696
#
# Epoch 27, CIFAR-10 Batch 2:  5000
# training loss       : 0.0877455621957779
# training accuracy : 1.0
# valid    accuracy : 0.7161998748779297
#
# Epoch 27, CIFAR-10 Batch 3:  5000
# training loss       : 0.12155984342098236
# training accuracy : 1.0
# valid    accuracy : 0.7249999046325684
#
# Epoch 27, CIFAR-10 Batch 4:  5000
# training loss       : 0.10791555047035217
# training accuracy : 1.0
# valid    accuracy : 0.7207998633384705
#
# Epoch 27, CIFAR-10 Batch 5:  5000
# training loss       : 0.13480496406555176
# training accuracy : 1.0
# valid    accuracy : 0.7295998334884644
#
# Epoch 28, CIFAR-10 Batch 1:  5000
# training loss       : 0.1492428183555603
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7177998423576355
#
# Epoch 28, CIFAR-10 Batch 2:  5000
# training loss       : 0.10803765058517456
# training accuracy : 1.0
# valid    accuracy : 0.7227998375892639
#
# Epoch 28, CIFAR-10 Batch 3:  5000
# training loss       : 0.10059471428394318
# training accuracy : 1.0
# valid    accuracy : 0.7205998301506042
#
# Epoch 28, CIFAR-10 Batch 4:  5000
# training loss       : 0.12655049562454224
# training accuracy : 0.9750000238418579
# valid    accuracy : 0.7117998600006104
#
# Epoch 28, CIFAR-10 Batch 5:  5000
# training loss       : 0.12586739659309387
# training accuracy : 1.0
# valid    accuracy : 0.7191998958587646
#
# Epoch 29, CIFAR-10 Batch 1:  5000
# training loss       : 0.12571030855178833
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7143998742103577
#
# Epoch 29, CIFAR-10 Batch 2:  5000
# training loss       : 0.11624674499034882
# training accuracy : 1.0
# valid    accuracy : 0.7111998796463013
#
# Epoch 29, CIFAR-10 Batch 3:  5000
# training loss       : 0.10255742073059082
# training accuracy : 1.0
# valid    accuracy : 0.7241998314857483
#
# Epoch 29, CIFAR-10 Batch 4:  5000
# training loss       : 0.07498637586832047
# training accuracy : 1.0
# valid    accuracy : 0.7165998816490173
#
# Epoch 29, CIFAR-10 Batch 5:  5000
# training loss       : 0.11202137917280197
# training accuracy : 1.0
# valid    accuracy : 0.7249998450279236
#
# Epoch 30, CIFAR-10 Batch 1:  5000
# training loss       : 0.19127461314201355
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7075998783111572
#
# Epoch 30, CIFAR-10 Batch 2:  5000
# training loss       : 0.10160315036773682
# training accuracy : 1.0
# valid    accuracy : 0.7207998037338257
#
# Epoch 30, CIFAR-10 Batch 3:  5000
# training loss       : 0.09384329617023468
# training accuracy : 1.0
# valid    accuracy : 0.72819983959198
#
# Epoch 30, CIFAR-10 Batch 4:  5000
# training loss       : 0.07958558201789856
# training accuracy : 1.0
# valid    accuracy : 0.7227998971939087
#
# Epoch 30, CIFAR-10 Batch 5:  5000
# training loss       : 0.13313768804073334
# training accuracy : 1.0
# valid    accuracy : 0.7273998260498047
#
# Epoch 31, CIFAR-10 Batch 1:  5000
# training loss       : 0.13576740026474
# training accuracy : 1.0
# valid    accuracy : 0.7261998653411865
#
# Epoch 31, CIFAR-10 Batch 2:  5000
# training loss       : 0.08028514683246613
# training accuracy : 1.0
# valid    accuracy : 0.7175998687744141
#
# Epoch 31, CIFAR-10 Batch 3:  5000
# training loss       : 0.11118271201848984
# training accuracy : 1.0
# valid    accuracy : 0.7209997773170471
#
# Epoch 31, CIFAR-10 Batch 4:  5000
# training loss       : 0.10407451540231705
# training accuracy : 1.0
# valid    accuracy : 0.7143998742103577
#
# Epoch 31, CIFAR-10 Batch 5:  5000
# training loss       : 0.09208256006240845
# training accuracy : 1.0
# valid    accuracy : 0.7255998849868774
#
# Epoch 32, CIFAR-10 Batch 1:  5000
# training loss       : 0.16356505453586578
# training accuracy : 0.925000011920929
# valid    accuracy : 0.7189998626708984
#
# Epoch 32, CIFAR-10 Batch 2:  5000
# training loss       : 0.07971691340208054
# training accuracy : 1.0
# valid    accuracy : 0.718599796295166
#
# Epoch 32, CIFAR-10 Batch 3:  5000
# training loss       : 0.10344211757183075
# training accuracy : 1.0
# valid    accuracy : 0.7201998829841614
#
# Epoch 32, CIFAR-10 Batch 4:  5000
# training loss       : 0.0645405575633049
# training accuracy : 1.0
# valid    accuracy : 0.7231997847557068
#
# Epoch 32, CIFAR-10 Batch 5:  5000
# training loss       : 0.074290931224823
# training accuracy : 1.0
# valid    accuracy : 0.7213998436927795
#
# Epoch 33, CIFAR-10 Batch 1:  5000
# training loss       : 0.11100365221500397
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7199998497962952
#
# Epoch 33, CIFAR-10 Batch 2:  5000
# training loss       : 0.05615409463644028
# training accuracy : 1.0
# valid    accuracy : 0.7243998050689697
#
# Epoch 33, CIFAR-10 Batch 3:  5000
# training loss       : 0.07563918083906174
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.731799840927124
#
# Epoch 33, CIFAR-10 Batch 4:  5000
# training loss       : 0.06000935286283493
# training accuracy : 1.0
# valid    accuracy : 0.723399817943573
#
# Epoch 33, CIFAR-10 Batch 5:  5000
# training loss       : 0.14184622466564178
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7147998809814453
#
# Epoch 34, CIFAR-10 Batch 1:  5000
# training loss       : 0.11817099899053574
# training accuracy : 1.0
# valid    accuracy : 0.7183998227119446
#
# Epoch 34, CIFAR-10 Batch 2:  5000
# training loss       : 0.04452832043170929
# training accuracy : 1.0
# valid    accuracy : 0.7165998220443726
#
# Epoch 34, CIFAR-10 Batch 3:  5000
# training loss       : 0.11631867289543152
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7153998613357544
#
# Epoch 34, CIFAR-10 Batch 4:  5000
# training loss       : 0.06955917179584503
# training accuracy : 1.0
# valid    accuracy : 0.7079998254776001
#
# Epoch 34, CIFAR-10 Batch 5:  5000
# training loss       : 0.09974940866231918
# training accuracy : 1.0
# valid    accuracy : 0.7193998694419861
#
# Epoch 35, CIFAR-10 Batch 1:  5000
# training loss       : 0.11405754089355469
# training accuracy : 1.0
# valid    accuracy : 0.7265998125076294
#
# Epoch 35, CIFAR-10 Batch 2:  5000
# training loss       : 0.09064750373363495
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7333998680114746
#
# Epoch 35, CIFAR-10 Batch 3:  5000
# training loss       : 0.08850924670696259
# training accuracy : 1.0
# valid    accuracy : 0.7243998646736145
#
# Epoch 35, CIFAR-10 Batch 4:  5000
# training loss       : 0.06324893981218338
# training accuracy : 1.0
# valid    accuracy : 0.7213998436927795
#
# Epoch 35, CIFAR-10 Batch 5:  5000
# training loss       : 0.08885654807090759
# training accuracy : 1.0
# valid    accuracy : 0.732999861240387
#
# Epoch 36, CIFAR-10 Batch 1:  5000
# training loss       : 0.10653340071439743
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7291998863220215
#
# Epoch 36, CIFAR-10 Batch 2:  5000
# training loss       : 0.041355032473802567
# training accuracy : 1.0
# valid    accuracy : 0.7313998341560364
#
# Epoch 36, CIFAR-10 Batch 3:  5000
# training loss       : 0.07205712795257568
# training accuracy : 1.0
# valid    accuracy : 0.7203998565673828
#
# Epoch 36, CIFAR-10 Batch 4:  5000
# training loss       : 0.06266941130161285
# training accuracy : 1.0
# valid    accuracy : 0.7343997955322266
#
# Epoch 36, CIFAR-10 Batch 5:  5000
# training loss       : 0.14105309545993805
# training accuracy : 1.0
# valid    accuracy : 0.7153998613357544
#
# Epoch 37, CIFAR-10 Batch 1:  5000
# training loss       : 0.16279618442058563
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7205998301506042
#
# Epoch 37, CIFAR-10 Batch 2:  5000
# training loss       : 0.08265732228755951
# training accuracy : 1.0
# valid    accuracy : 0.7209998965263367
#
# Epoch 37, CIFAR-10 Batch 3:  5000
# training loss       : 0.07224629074335098
# training accuracy : 1.0
# valid    accuracy : 0.7217998504638672
#
# Epoch 37, CIFAR-10 Batch 4:  5000
# training loss       : 0.11543815582990646
# training accuracy : 1.0
# valid    accuracy : 0.7101998329162598
#
# Epoch 37, CIFAR-10 Batch 5:  5000
# training loss       : 0.07692447304725647
# training accuracy : 1.0
# valid    accuracy : 0.7081998586654663
#
# Epoch 38, CIFAR-10 Batch 1:  5000
# training loss       : 0.11147121340036392
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7247998118400574
#
# Epoch 38, CIFAR-10 Batch 2:  5000
# training loss       : 0.0566103532910347
# training accuracy : 1.0
# valid    accuracy : 0.7337998747825623
#
# Epoch 38, CIFAR-10 Batch 3:  5000
# training loss       : 0.06559306383132935
# training accuracy : 1.0
# valid    accuracy : 0.7257997989654541
#
# Epoch 38, CIFAR-10 Batch 4:  5000
# training loss       : 0.06058065593242645
# training accuracy : 1.0
# valid    accuracy : 0.7171998620033264
#
# Epoch 38, CIFAR-10 Batch 5:  5000
# training loss       : 0.0913894772529602
# training accuracy : 1.0
# valid    accuracy : 0.7273998856544495
#
# Epoch 39, CIFAR-10 Batch 1:  5000
# training loss       : 0.10022031515836716
# training accuracy : 0.9749999642372131
# valid    accuracy : 0.7375998497009277
#
# Epoch 39, CIFAR-10 Batch 2:  5000
# training loss       : 0.053603146225214005
# training accuracy : 1.0
# valid    accuracy : 0.7331998944282532
#
# Epoch 39, CIFAR-10 Batch 3:  5000
# training loss       : 0.05224521830677986
# training accuracy : 1.0
# valid    accuracy : 0.7337998747825623
#
# Epoch 39, CIFAR-10 Batch 4:  5000
# training loss       : 0.04668353497982025
# training accuracy : 1.0
# valid    accuracy : 0.7275998592376709
#
# Epoch 39, CIFAR-10 Batch 5:  5000
# training loss       : 0.06204109266400337
# training accuracy : 1.0
# valid    accuracy : 0.7171999216079712
#
# Epoch 40, CIFAR-10 Batch 1:  5000
# training loss       : 0.10443936288356781
# training accuracy : 1.0
# valid    accuracy : 0.7303998470306396
#
# Epoch 40, CIFAR-10 Batch 2:  5000
# training loss       : 0.06549136340618134
# training accuracy : 1.0
# valid    accuracy : 0.7261998057365417
#
# Epoch 40, CIFAR-10 Batch 3:  5000
# training loss       : 0.05790398269891739
# training accuracy : 1.0
# valid    accuracy : 0.7407997846603394
#
# Epoch 40, CIFAR-10 Batch 4:  5000
# training loss       : 0.05628988519310951
# training accuracy : 1.0
# valid    accuracy : 0.7231998443603516
#
# Epoch 40, CIFAR-10 Batch 5:  5000
# training loss       : 0.057234108448028564
# training accuracy : 1.0
# valid    accuracy : 0.7297998666763306

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7274525316455697

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
